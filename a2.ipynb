# %%
from IPython.display import Image

# %%
filenames = {
    'q1': [
        "Difference in Percentage of Girls Out of School and Percentage of Boys Out of School.png",
        "Actual Fertility Rates and Wanted Fertility Rates, with Girls' Schooling.png",
        "Girls' Schooling and the Difference Between Actual and Wanted Fertility Rates.png",
        "Girls' Schooling and Contraception Use, With Fertility Rate.png",
        "Contraceptive Prevalence and Actual versus Wanted Fertility Rates.png",
    ],
    'q2': [
        "World-Wide Sources of Electricity Production.png",
        "Percentage of World-Wide Electricity Coming From Renewable Sources (excluding hydroelectric power).png",
        "Zoomed_Out Percentage of World-Wide Electricity Coming from Renewable Sources (excluding hydroelectric power).png",
    ],
    'q3': [
        "Income Inequality in the United States and World-Wide.png",
        "United States Income Share by Quintile Over Time.png",
    ]
}

# %%
def show_img(q, subpart):
    return Image(filename=filenames[q][subpart])

# %% [markdown]
# # Data Source
#
# ### I considered the World Bank Data, available from https://github.com/ZeningQu/World-Bank-Data-by-Indicators, which contains data for many countries and regions spanning 1960 - 2017. I specifically focused on their climate change, education, gender, and poverty statistics.

# %% [markdown]
# # Question 1: How do rates' in girls' education impact fertility rates and contraception use?

# %%
show_img('q1', 0)

# %%
show_img('q1', 1)

# %%
show_img('q1', 2)

# %%
show_img('q1', 3)

# %%
show_img('q1', 4)

# %% [markdown]
# # Question 2: How have world-wide energy sources changed over time? Are they becoming more sustainable?

# %%
show_img('q2', 0)

# %%
show_img('q2', 1)

# %%
show_img('q2', 2)

# %% [markdown]
# # Question 3: How has the income gap worsened (or improved) over time, and how does the rest of the world compare to the United States?

# %%
show_img('q3', 0)

# %%
show_img('q3', 1)
